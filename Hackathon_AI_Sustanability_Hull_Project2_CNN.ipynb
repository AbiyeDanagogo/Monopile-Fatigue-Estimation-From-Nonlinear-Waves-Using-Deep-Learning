# %% [markdown]
# # Hackathon in AI for Sustainability - University of Hull, 28th March - 1st April 2022.
# ## Project 2: Monopile fatigue estimation from nonlinear waves using deep learning.
#
# ---

# %% [markdown]
# Welcome and thank you for participating in this Hackathon Project!
#
# This project is based around the development of a machine learning model (meta-model) to predict the damage fraction (D) of an example offshore wind turbine monopile. Here, the damage fraction defines the amount of damage (loss of structural integrity) the monopile incurs over a give period (1-hour) and is dependent of the following 'environmental' or 'metocean' (wind and wave) variables:
#
# - Significant wave height, Hs (m)
# - Peak wave period, Tp (s)
# - Mean hub height wind speed, Uw (m/s)
#
# and the operational state of the turbine, State (-); whereby '1' is an operational turbine, '2' is a parked turbine.
#
# This following example code is separated into two parts:
# - Part 1: Development of a meta-model to predict monopile damage fraction (Example code based on convolutional neural networks)
# - Part 2: Calculation of estimated damage from developed meta-model for an example dataset
#
# The aim of this project is to:
#
# 1. Benchmark the performance of a variety of different neural networks (e.g. recurrent neural networks, transformer networks, convolutional neural networks) to establish which family of deep learning model is the most
# suitable to this task and project
# 2. Evaluate whether a reliable meta-model can be developed by using fewer inputs data points (i.e. randomly selecting less training data).
#
#
# Finally, a third dataset is available for testing the model. 13 additional damage fraction values have been numerically simulated based on 'data lumping' methods (introduced in project overview presentation) - these can be used to provide a secondary validation of any meta-models by comparing the model outputs for these loading case inputs, and the model predicted damage fraction value.
#
#
# The code provided below can be run directly here. If you wish to edit/build on this code, please made a copy to your own Google Drive along with the required datasets in the root folder "HullUniversity_AI_Sustanability_Hackathon_Project2".

# %% [markdown]
# ### Part 1: Development of a meta-model to predict monopile damage fraction
#
# ### (Example code based on convolutioal neural networks)

# %% [markdown]
# Numerical simulations and calculations have been conducted based on example turbine, and provides the damage fraction for a myriad of combinations of the variables above, this is stored in the file named "FNL_Damage_Hackathon.csv" located in the root folder.
#
# This forms the training (and test) dataset to enable development of deep learning based model to predict the damage fraction for any given input metocean condition.
#
# First, connect to your google drive where you have saved the input datafiles.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Import required packages.

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

import keras as keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv1D, MaxPooling1D, BatchNormalization
from keras import backend as K

print("TensorFlow version:", tf.__version__)
print(keras.__version__)
# Out:
# TensorFlow version: 2.8.0
# 2.8.0

# %% [markdown]
# Load training dataset and remove any NaN values and outliers (threshold not justified here).

# %%
data=pd.read_csv('gdrive/My Drive/HullUniversity_AI_Sustanability_Hackathon_Project2/FNL_Damage_Hackathon.csv') # correct file location as required
data = data.dropna() # remove NaN data entries

valid_values = abs(data['D'] < 0.0030) # remove outliers
data = data[valid_values]

# %% [markdown]
# View imported dataset, which includes the following variables per column
# - Tp= Peak wave period (s)
# - Hs = Significant wave height (m)
# - Uw = Mean wind speed at turbine hub height (m/s)
# - Op = Turbine opperatinal state, whereby 1 = opperational, and 2 = parked
# - D = Hourly monopile damage fraction associated with the above variables.

# %%
data.head() # display data
# Out:
#     Tp        Hs  Uw  Op             D
# 0  2.0  0.004385   1   1  1.760000e-09
# 2  2.0  0.004385   2   1  1.500000e-06
# 3  2.0  0.004385   2   2  5.710000e-10
# 4  2.0  0.004385   3   1  1.900000e-07
# 5  2.0  0.004385   3   2  4.530000e-10

# %% [markdown]
# Select training inputs data, and remove any unwanted columns from inputs dataset.

# %%
y=data[['D']]
x=data.drop(columns=['D'])
x.head()
# Out:
#     Tp        Hs  Uw  Op
# 0  2.0  0.004385   1   1
# 2  2.0  0.004385   2   1
# 3  2.0  0.004385   2   2
# 4  2.0  0.004385   3   1
# 5  2.0  0.004385   3   2

# %% [markdown]
# Create training and test datasets. Set test:train ratio (80:20 split used in this example)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2, random_state=42)

# %% [markdown]
# Normalise the input data, and reshape for input into convolutional neural network.

# %%
FNL_output_scaler = MinMaxScaler(feature_range=(0, 1), copy=False) # create scaler
FNL_output_scaler.fit(y_train)
y_train=FNL_output_scaler.transform(y_train)
y_test=FNL_output_scaler.transform(y_test)

FNL_input_scaler = MinMaxScaler(feature_range=(0, 1), copy=False) # create scaler
FNL_input_scaler.fit(x_train)
x_train=FNL_input_scaler.transform(x_train)
x_test=FNL_input_scaler.transform(x_test)

x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], 1)
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1], 1)

# %% [markdown]
# Create CNN model

# %%
verbose, epochs, batch_size = 1, 100, 64
		
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=9, padding='same', activation='relu', 
                 input_shape=(x_train.shape[1],x_train.shape[2])))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Conv1D(filters=32, kernel_size=7, padding='same', activation='relu', 
                 input_shape=(x_train.shape[1],x_train.shape[2])))

model.add(MaxPooling1D())
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(32, activation='relu'))
model.add(Dense(1))

model.compile(loss='mse', optimizer='adam', 
              metrics=[tf.keras.metrics.MeanAbsolutePercentageError()])
 
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 4, 64)             640
#
#  batch_normalization (BatchN  (None, 4, 64)            256
#  ormalization)
#
#  dropout (Dropout)           (None, 4, 64)             0
#
#  conv1d_1 (Conv1D)           (None, 4, 32)             14368
#
#  max_pooling1d (MaxPooling1D  (None, 2, 32)            0
#  )
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense (Dense)               (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 21,537
# Trainable params: 21,409
# Non-trainable params: 128
# _________________________________________________________________

# %% [markdown]
# Fit (Train) model

# %%
history = model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, 
                    verbose=verbose, validation_data=(x_test, y_test), 
                    shuffle=True)
# Out:
# Epoch 1/100
# 213/213 [==============================] - 2s 6ms/step - loss: 0.0179 - mean_absolute_percentage_error: 3081597.7500 - val_loss: 0.0130 - val_mean_absolute_percentage_error: 137055.9844
# Epoch 2/100
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0085 - mean_absolute_percentage_error: 1033741.1875 - val_loss: 0.0099 - val_mean_absolute_percentage_error: 244896.6094
# Epoch 3/100
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0066 - mean_absolute_percentage_error: 771686.0625 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 285042.0312
# Epoch 4/100
# 213/213 [==============================] - 1s 5ms/step - loss: 0.0051 - mean_absolute_percentage_error: 622596.2500 - val_loss: 0.0035 - val_mean_absolute_percentage_error: 380433.5938
# Epoch 5/100
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0044 - mean_absolute_percentage_error: 593055.4375 - val_loss: 0.0041 - val_mean_absolute_percentage_error: 388516.4688
# Epoch 6/100
# 213/213 [==============================] - 1s 5ms/step - loss: 0.0033 - mean_absolute_percentage_error: 481012.8438 - val_loss: 0.0081 - val_mean_absolute_percentage_error: 198020.4688
# Epoch 7/100
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0031 - mean_absolute_percentage_error: 435068.2188 - val_loss: 0.0019 - val_mean_absolute_percentage_error: 213075.2344
# Epoch 8/100
# 213/213 [==============================] - 2s 10ms/step - loss: 0.0029 - mean_absolute_percentage_error: 388178.5625 - val_loss: 0.0015 - val_mean_absolute_percentage_error: 144134.3125
# Epoch 9/100
# 213/213 [==============================] - 2s 10ms/step - loss: 0.0025 - mean_absolute_percentage_error: 346946.4688 - val_loss: 9.2332e-04 - val_mean_absolute_percentage_error: 254857.6094
# Epoch 10/100
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0023 - mean_absolute_percentage_error: 342883.2812 - val_loss: 6.6126e-04 - val_mean_absolute_percentage_error: 177994.8281
# Epoch 11/100
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0024 - mean_absolute_percentage_error: 309976.9375 - val_loss: 9.1489e-04 - val_mean_absolute_percentage_error: 171684.7500
# Epoch 12/100
# 213/213 [==============================] - 1s 5ms/step - loss: 0.0017 - mean_absolute_percentage_error: 286273.0938 - val_loss: 8.5932e-04 - val_mean_absolute_percentage_error: 130896.2812
# Epoch 13/100
# 213/213 [==============================] - 1s 5ms/step - loss: 0.0020 - mean_absolute_percentage_error: 260296.8906 - val_loss: 8.6896e-04 - val_mean_absolute_percentage_error: 93168.6797
# Epoch 14/100
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0019 - mean_absolute_percentage_error: 227837.8750 - val_loss: 0.0012 - val_mean_absolute_percentage_error: 191180.3594
# Epoch 15/100
# 213/213 [==============================] - 1s 5ms/step - loss: 0.0017 - mean_absolute_percentage_error: 234413.2500 - val_loss: 5.6201e-04 - val_mean_absolute_percentage_error: 150577.5000
# Epoch 16/100
# 213/213 [==============================] - 1s 5ms/step - loss: 0.0013 - mean_absolute_percentage_error: 215458.6250 - val_loss: 0.0012 - val_mean_absolute_percentage_error: 79176.4375
# Epoch 17/100
# 213/213 [==============================] - 1s 5ms/step - loss: 0.0015 - mean_absolute_percentage_error: 201302.2812 - val_loss: 6.5018e-04 - val_mean_absolute_percentage_error: 85023.5547
# Epoch 18/100
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0012 - mean_absolute_percentage_error: 197619.2500 - val_loss: 5.3856e-04 - val_mean_absolute_percentage_error: 164052.6250
# Epoch 19/100
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0014 - mean_absolute_percentage_error: 206763.8750 - val_loss: 4.9284e-04 - val_mean_absolute_percentage_error: 105812.6406
# Epoch 20/100
# 213/213 [==============================] - 1s 5ms/step - loss: 0.0012 - mean_absolute_percentage_error: 175919.7031 - val_loss: 9.8199e-04 - val_mean_absolute_percentage_error: 192967.6562
# Epoch 21/100
# 213/213 [==============================] - 1s 5ms/step - loss: 9.5886e-04 - mean_absolute_percentage_error: 178241.8438 - val_loss: 5.3680e-04 - val_mean_absolute_percentage_error: 87655.8203
# Epoch 22/100
# 213/213 [==============================] - 1s 5ms/step - loss: 8.7866e-04 - mean_absolute_percentage_error: 155679.6406 - val_loss: 5.0726e-04 - val_mean_absolute_percentage_error: 78779.0547
# Epoch 23/100
# 213/213 [==============================] - 1s 6ms/step - loss: 9.6946e-04 - mean_absolute_percentage_error: 169225.1719 - val_loss: 4.8853e-04 - val_mean_absolute_percentage_error: 107293.4688
# Epoch 24/100
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0016 - mean_absolute_percentage_error: 171646.1406 - val_loss: 6.4263e-04 - val_mean_absolute_percentage_error: 130722.0234
# Epoch 25/100
# 213/213 [==============================] - 1s 5ms/step - loss: 8.8706e-04 - mean_absolute_percentage_error: 157386.5625 - val_loss: 4.9065e-04 - val_mean_absolute_percentage_error: 60621.7500
# Epoch 26/100
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0010 - mean_absolute_percentage_error: 154002.2188 - val_loss: 9.0932e-04 - val_mean_absolute_percentage_error: 46335.9609
# Epoch 27/100
# 213/213 [==============================] - 1s 5ms/step - loss: 0.0010 - mean_absolute_percentage_error: 132273.6562 - val_loss: 4.8228e-04 - val_mean_absolute_percentage_error: 60193.4023
# Epoch 28/100
# 213/213 [==============================] - 1s 6ms/step - loss: 8.6464e-04 - mean_absolute_percentage_error: 119073.9531 - val_loss: 0.0012 - val_mean_absolute_percentage_error: 79248.4297
# Epoch 29/100
# 213/213 [==============================] - 1s 6ms/step - loss: 9.7469e-04 - mean_absolute_percentage_error: 128271.2578 - val_loss: 6.5702e-04 - val_mean_absolute_percentage_error: 172416.2500
# Epoch 30/100
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0018 - mean_absolute_percentage_error: 178870.4062 - val_loss: 4.8781e-04 - val_mean_absolute_percentage_error: 129907.5781
# Epoch 31/100
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0010 - mean_absolute_percentage_error: 123450.0938 - val_loss: 4.9795e-04 - val_mean_absolute_percentage_error: 87573.6484
# Epoch 32/100
# 213/213 [==============================] - 1s 6ms/step - loss: 7.9790e-04 - mean_absolute_percentage_error: 127854.9531 - val_loss: 6.3542e-04 - val_mean_absolute_percentage_error: 32647.4434
# Epoch 33/100
# 213/213 [==============================] - 1s 6ms/step - loss: 9.2565e-04 - mean_absolute_percentage_error: 133390.2031 - val_loss: 6.8482e-04 - val_mean_absolute_percentage_error: 20387.2773
# Epoch 34/100
# 213/213 [==============================] - 1s 6ms/step - loss: 6.4029e-04 - mean_absolute_percentage_error: 121175.5391 - val_loss: 5.5377e-04 - val_mean_absolute_percentage_error: 148719.0625
# Epoch 35/100
# 213/213 [==============================] - 1s 6ms/step - loss: 9.2087e-04 - mean_absolute_percentage_error: 142431.1406 - val_loss: 5.0906e-04 - val_mean_absolute_percentage_error: 127810.2031
# Epoch 36/100
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0018 - mean_absolute_percentage_error: 187986.7031 - val_loss: 5.4099e-04 - val_mean_absolute_percentage_error: 87778.3516
# Epoch 37/100
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0011 - mean_absolute_percentage_error: 117318.7344 - val_loss: 5.2958e-04 - val_mean_absolute_percentage_error: 160550.9844
# Epoch 38/100
# 213/213 [==============================] - 1s 6ms/step - loss: 8.1873e-04 - mean_absolute_percentage_error: 101467.0625 - val_loss: 5.3517e-04 - val_mean_absolute_percentage_error: 200371.3438
# Epoch 39/100
# 213/213 [==============================] - 1s 6ms/step - loss: 8.5095e-04 - mean_absolute_percentage_error: 103813.9531 - val_loss: 0.0012 - val_mean_absolute_percentage_error: 106523.9297
# Epoch 40/100
# 213/213 [==============================] - 1s 6ms/step - loss: 5.9486e-04 - mean_absolute_percentage_error: 99482.5000 - val_loss: 4.8359e-04 - val_mean_absolute_percentage_error: 103901.5156
# Epoch 41/100
# 213/213 [==============================] - 1s 6ms/step - loss: 8.2418e-04 - mean_absolute_percentage_error: 120138.0781 - val_loss: 0.0011 - val_mean_absolute_percentage_error: 130445.6562
# Epoch 42/100
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0015 - mean_absolute_percentage_error: 143643.2500 - val_loss: 0.0010 - val_mean_absolute_percentage_error: 159099.6406
# Epoch 43/100
# 213/213 [==============================] - 1s 5ms/step - loss: 0.0012 - mean_absolute_percentage_error: 153100.2812 - val_loss: 5.0101e-04 - val_mean_absolute_percentage_error: 42163.2812
# Epoch 44/100
# 213/213 [==============================] - 1s 6ms/step - loss: 7.9654e-04 - mean_absolute_percentage_error: 115671.5781 - val_loss: 7.8130e-04 - val_mean_absolute_percentage_error: 159809.9219
# Epoch 45/100
# 213/213 [==============================] - 1s 5ms/step - loss: 7.3155e-04 - mean_absolute_percentage_error: 91995.2344 - val_loss: 5.4095e-04 - val_mean_absolute_percentage_error: 34635.9062
# Epoch 46/100
# 213/213 [==============================] - 1s 6ms/step - loss: 8.0472e-04 - mean_absolute_percentage_error: 139359.2344 - val_loss: 4.5258e-04 - val_mean_absolute_percentage_error: 35575.5625
# Epoch 47/100
# 213/213 [==============================] - 1s 6ms/step - loss: 7.8486e-04 - mean_absolute_percentage_error: 86320.2188 - val_loss: 6.0531e-04 - val_mean_absolute_percentage_error: 51250.1445
# Epoch 48/100
# 213/213 [==============================] - 1s 5ms/step - loss: 9.1587e-04 - mean_absolute_percentage_error: 130181.9688 - val_loss: 5.4577e-04 - val_mean_absolute_percentage_error: 96030.1406
# Epoch 49/100
# 213/213 [==============================] - 1s 6ms/step - loss: 7.3827e-04 - mean_absolute_percentage_error: 145218.6406 - val_loss: 6.0582e-04 - val_mean_absolute_percentage_error: 95594.4531
# Epoch 50/100
# 213/213 [==============================] - 1s 6ms/step - loss: 5.9144e-04 - mean_absolute_percentage_error: 103102.2656 - val_loss: 5.3165e-04 - val_mean_absolute_percentage_error: 73919.5781
# Epoch 51/100
# 213/213 [==============================] - 1s 6ms/step - loss: 6.2352e-04 - mean_absolute_percentage_error: 118134.0234 - val_loss: 6.7373e-04 - val_mean_absolute_percentage_error: 190818.3906
# Epoch 52/100
# 213/213 [==============================] - 1s 6ms/step - loss: 7.0244e-04 - mean_absolute_percentage_error: 104281.3594 - val_loss: 6.2700e-04 - val_mean_absolute_percentage_error: 53679.1758
# Epoch 53/100
# 213/213 [==============================] - 1s 6ms/step - loss: 7.4711e-04 - mean_absolute_percentage_error: 126123.8047 - val_loss: 7.3238e-04 - val_mean_absolute_percentage_error: 33095.5938
# Epoch 54/100
# 213/213 [==============================] - 1s 6ms/step - loss: 7.7569e-04 - mean_absolute_percentage_error: 114837.0938 - val_loss: 5.2389e-04 - val_mean_absolute_percentage_error: 108746.5234
# Epoch 55/100
# 213/213 [==============================] - 1s 6ms/step - loss: 8.4008e-04 - mean_absolute_percentage_error: 148865.9844 - val_loss: 4.8993e-04 - val_mean_absolute_percentage_error: 146338.8438
# Epoch 56/100
# 213/213 [==============================] - 1s 6ms/step - loss: 5.6447e-04 - mean_absolute_percentage_error: 112712.5000 - val_loss: 4.6162e-04 - val_mean_absolute_percentage_error: 213636.1406
# Epoch 57/100
# 213/213 [==============================] - 1s 6ms/step - loss: 6.0643e-04 - mean_absolute_percentage_error: 129440.3203 - val_loss: 8.2404e-04 - val_mean_absolute_percentage_error: 178259.2188
# Epoch 58/100
# 213/213 [==============================] - 1s 6ms/step - loss: 8.2822e-04 - mean_absolute_percentage_error: 111572.0547 - val_loss: 4.7242e-04 - val_mean_absolute_percentage_error: 29823.0508
# Epoch 59/100
# 213/213 [==============================] - 1s 6ms/step - loss: 7.3619e-04 - mean_absolute_percentage_error: 142544.6094 - val_loss: 0.0031 - val_mean_absolute_percentage_error: 42565.6094
# Epoch 60/100
# 213/213 [==============================] - 1s 6ms/step - loss: 8.5506e-04 - mean_absolute_percentage_error: 111478.6719 - val_loss: 8.0944e-04 - val_mean_absolute_percentage_error: 92524.3047
# Epoch 61/100
# 213/213 [==============================] - 1s 6ms/step - loss: 6.0670e-04 - mean_absolute_percentage_error: 102514.8594 - val_loss: 5.2553e-04 - val_mean_absolute_percentage_error: 38125.2031
# Epoch 62/100
# 213/213 [==============================] - 1s 6ms/step - loss: 8.4369e-04 - mean_absolute_percentage_error: 156929.3750 - val_loss: 0.0050 - val_mean_absolute_percentage_error: 170670.4375
# Epoch 63/100
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0010 - mean_absolute_percentage_error: 157308.3750 - val_loss: 5.0975e-04 - val_mean_absolute_percentage_error: 70181.3125
# Epoch 64/100
# 213/213 [==============================] - 1s 5ms/step - loss: 9.3396e-04 - mean_absolute_percentage_error: 122751.8047 - val_loss: 5.3914e-04 - val_mean_absolute_percentage_error: 166481.4219
# Epoch 65/100
# 213/213 [==============================] - 1s 6ms/step - loss: 6.1273e-04 - mean_absolute_percentage_error: 110583.3359 - val_loss: 4.7208e-04 - val_mean_absolute_percentage_error: 15673.4062
# Epoch 66/100
# 213/213 [==============================] - 1s 6ms/step - loss: 7.3441e-04 - mean_absolute_percentage_error: 94861.7031 - val_loss: 6.4768e-04 - val_mean_absolute_percentage_error: 67965.2344
# Epoch 67/100
# 213/213 [==============================] - 1s 5ms/step - loss: 5.5839e-04 - mean_absolute_percentage_error: 104226.2109 - val_loss: 5.0653e-04 - val_mean_absolute_percentage_error: 28201.8066
# Epoch 68/100
# 213/213 [==============================] - 1s 6ms/step - loss: 7.8896e-04 - mean_absolute_percentage_error: 103597.4531 - val_loss: 5.4231e-04 - val_mean_absolute_percentage_error: 71354.4062
# Epoch 69/100
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0012 - mean_absolute_percentage_error: 108966.1328 - val_loss: 8.0654e-04 - val_mean_absolute_percentage_error: 40800.1133
# Epoch 70/100
# 213/213 [==============================] - 1s 5ms/step - loss: 5.5276e-04 - mean_absolute_percentage_error: 123871.9062 - val_loss: 4.9188e-04 - val_mean_absolute_percentage_error: 106059.4062
# Epoch 71/100
# 213/213 [==============================] - 1s 6ms/step - loss: 4.9998e-04 - mean_absolute_percentage_error: 108227.5703 - val_loss: 4.6419e-04 - val_mean_absolute_percentage_error: 85915.2891
# Epoch 72/100
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0013 - mean_absolute_percentage_error: 159365.6562 - val_loss: 4.5932e-04 - val_mean_absolute_percentage_error: 37039.4141
# Epoch 73/100
# 213/213 [==============================] - 1s 6ms/step - loss: 6.1453e-04 - mean_absolute_percentage_error: 94866.9922 - val_loss: 4.8763e-04 - val_mean_absolute_percentage_error: 162575.4375
# Epoch 74/100
# 213/213 [==============================] - 1s 5ms/step - loss: 5.7227e-04 - mean_absolute_percentage_error: 118280.0938 - val_loss: 5.7340e-04 - val_mean_absolute_percentage_error: 159296.4844
# Epoch 75/100
# 213/213 [==============================] - 2s 8ms/step - loss: 7.5837e-04 - mean_absolute_percentage_error: 116478.1875 - val_loss: 4.6828e-04 - val_mean_absolute_percentage_error: 27000.2988
# Epoch 76/100
# 213/213 [==============================] - 1s 5ms/step - loss: 6.4868e-04 - mean_absolute_percentage_error: 95211.3125 - val_loss: 5.2332e-04 - val_mean_absolute_percentage_error: 189362.7344
# Epoch 77/100
# 213/213 [==============================] - 1s 6ms/step - loss: 5.6577e-04 - mean_absolute_percentage_error: 119960.7266 - val_loss: 6.0708e-04 - val_mean_absolute_percentage_error: 42335.0469
# Epoch 78/100
# 213/213 [==============================] - 1s 5ms/step - loss: 5.4943e-04 - mean_absolute_percentage_error: 118822.1172 - val_loss: 5.0842e-04 - val_mean_absolute_percentage_error: 77582.3438
# Epoch 79/100
# 213/213 [==============================] - 1s 5ms/step - loss: 5.3043e-04 - mean_absolute_percentage_error: 100103.2891 - val_loss: 4.8014e-04 - val_mean_absolute_percentage_error: 27872.9727
# Epoch 80/100
# 213/213 [==============================] - 1s 6ms/step - loss: 5.6929e-04 - mean_absolute_percentage_error: 105777.7969 - val_loss: 5.0101e-04 - val_mean_absolute_percentage_error: 202366.4531
# Epoch 81/100
# 213/213 [==============================] - 1s 6ms/step - loss: 7.0589e-04 - mean_absolute_percentage_error: 118097.2734 - val_loss: 4.7658e-04 - val_mean_absolute_percentage_error: 69560.3828
# Epoch 82/100
# 213/213 [==============================] - 1s 5ms/step - loss: 6.7362e-04 - mean_absolute_percentage_error: 130866.5234 - val_loss: 7.2351e-04 - val_mean_absolute_percentage_error: 84394.5156
# Epoch 83/100
# 213/213 [==============================] - 1s 6ms/step - loss: 6.8532e-04 - mean_absolute_percentage_error: 118075.8516 - val_loss: 4.5226e-04 - val_mean_absolute_percentage_error: 78554.0547
# Epoch 84/100
# 213/213 [==============================] - 1s 6ms/step - loss: 4.6146e-04 - mean_absolute_percentage_error: 93470.9922 - val_loss: 5.0854e-04 - val_mean_absolute_percentage_error: 124974.0703
# Epoch 85/100
# 213/213 [==============================] - 1s 6ms/step - loss: 9.6169e-04 - mean_absolute_percentage_error: 131453.1406 - val_loss: 6.8508e-04 - val_mean_absolute_percentage_error: 223244.6406
# Epoch 86/100
# 213/213 [==============================] - 1s 6ms/step - loss: 5.5774e-04 - mean_absolute_percentage_error: 120418.2109 - val_loss: 5.2195e-04 - val_mean_absolute_percentage_error: 120954.7500
# Epoch 87/100
# 213/213 [==============================] - 1s 6ms/step - loss: 7.3989e-04 - mean_absolute_percentage_error: 117062.0391 - val_loss: 4.5429e-04 - val_mean_absolute_percentage_error: 156408.8438
# Epoch 88/100
# 213/213 [==============================] - 1s 6ms/step - loss: 5.9990e-04 - mean_absolute_percentage_error: 115115.2031 - val_loss: 4.9237e-04 - val_mean_absolute_percentage_error: 23184.4199
# Epoch 89/100
# 213/213 [==============================] - 1s 5ms/step - loss: 3.7682e-04 - mean_absolute_percentage_error: 103937.7422 - val_loss: 6.3060e-04 - val_mean_absolute_percentage_error: 73583.3750
# Epoch 90/100
# 213/213 [==============================] - 1s 6ms/step - loss: 6.2788e-04 - mean_absolute_percentage_error: 113070.0391 - val_loss: 5.0358e-04 - val_mean_absolute_percentage_error: 216808.0156
# Epoch 91/100
# 213/213 [==============================] - 1s 6ms/step - loss: 9.2568e-04 - mean_absolute_percentage_error: 128598.9922 - val_loss: 5.1790e-04 - val_mean_absolute_percentage_error: 114303.0078
# Epoch 92/100
# 213/213 [==============================] - 1s 6ms/step - loss: 6.9681e-04 - mean_absolute_percentage_error: 114740.1562 - val_loss: 4.9079e-04 - val_mean_absolute_percentage_error: 38422.5234
# Epoch 93/100
# 213/213 [==============================] - 1s 6ms/step - loss: 4.1451e-04 - mean_absolute_percentage_error: 101495.5781 - val_loss: 4.8869e-04 - val_mean_absolute_percentage_error: 88876.8984
# Epoch 94/100
# 213/213 [==============================] - 1s 5ms/step - loss: 4.0933e-04 - mean_absolute_percentage_error: 100611.3281 - val_loss: 4.6925e-04 - val_mean_absolute_percentage_error: 44543.4023
# Epoch 95/100
# 213/213 [==============================] - 1s 6ms/step - loss: 4.8554e-04 - mean_absolute_percentage_error: 94673.3594 - val_loss: 4.8735e-04 - val_mean_absolute_percentage_error: 133664.6875
# Epoch 96/100
# 213/213 [==============================] - 1s 5ms/step - loss: 7.4163e-04 - mean_absolute_percentage_error: 117601.2734 - val_loss: 0.0011 - val_mean_absolute_percentage_error: 159938.4844
# Epoch 97/100
# 213/213 [==============================] - 1s 6ms/step - loss: 6.0693e-04 - mean_absolute_percentage_error: 124715.0234 - val_loss: 0.0015 - val_mean_absolute_percentage_error: 132302.8594
# Epoch 98/100
# 213/213 [==============================] - 1s 6ms/step - loss: 5.0752e-04 - mean_absolute_percentage_error: 121727.7656 - val_loss: 5.6652e-04 - val_mean_absolute_percentage_error: 48236.8594
# Epoch 99/100
# 213/213 [==============================] - 1s 6ms/step - loss: 8.8350e-04 - mean_absolute_percentage_error: 116904.3750 - val_loss: 6.1574e-04 - val_mean_absolute_percentage_error: 146724.2812
# Epoch 100/100
# 213/213 [==============================] - 1s 5ms/step - loss: 7.9921e-04 - mean_absolute_percentage_error: 154312.0938 - val_loss: 4.5378e-04 - val_mean_absolute_percentage_error: 149991.2031

# %% [markdown]
# Predict model results based on test data inputs

# %%
y_test_pred=model.predict(x_test)

print(model.evaluate(x_train,y_train))
print("Test data MSE: %.6f" % mean_squared_error(y_test, y_test_pred))
# Out:
# 425/425 [==============================] - 2s 6ms/step - loss: 2.7978e-04 - mean_absolute_percentage_error: 135692.2344
# [0.0002797767228912562, 135692.234375]
# Test data MSE: 0.000454

# %% [markdown]
# Plot results between model predicted damage and simulated damage.

# %%
plt.figure(1)
plt.rcParams["mathtext.default"]
plt.scatter(y_test,y_test_pred) # plot predicted v origonal
plt.xlabel(r'$D_{j,hr} \/$' '(Normalised Simulated Values)')
plt.ylabel(r'$D_{j,hr} \/$' '(Normalised Predicted Values)')
lims = [0, 1]
plt.xlim(lims)
plt.ylim(lims)

xplot = np.linspace(0,1,100)
yplot = xplot
plt.plot(xplot, yplot, '--r')

# %% [markdown]
# Plot result residuals, and calculate r-squared score

# %%
import seaborn as sns
residuals = y_test - y_test_pred
sns.distplot(residuals)
plt.xlabel(r'Residual')
plt.ylabel(r'Count')

plt.savefig('FNL_cnn_model_residuals_23022022_2.png',dpi=300)

from sklearn.metrics import r2_score
r2_score(y_test, y_test_pred)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 0.9611552464166416

# %% [markdown]
# Plot model loss and accuracy

# %%
print(history.history.keys())

from cycler import cycler

plt.figure(1)
plt.rcParams['axes.prop_cycle'] = cycler(color=['k', 'r', 'b', 'g'])
plt.rcParams['font.family'] = 'Serif'

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('Loss (MSE)')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.savefig('FNL_cnn_loss_23022022_2.png',dpi=300)

plt.show()
# Out:
# dict_keys(['loss', 'mean_absolute_percentage_error', 'val_loss', 'val_mean_absolute_percentage_error'])

# %% [markdown]
# Save model

# %%
model.save('FNL_Damage_CNN_model_hackathon')
model.save('FNL_Damage_CNN_model_hackathon.h5')

#from sklearn.externals import joblib
#joblib.dump(FNL_output_scaler, "FNL_output_scaler") 
#joblib.dump(FNL_input_scaler, "FNL_input_scaler")
# Out:
# INFO:tensorflow:Assets written to: FNL_Damage_CNN_model_hackathon/assets

# %% [markdown]
# ### Part 2: Calculation of estimated damage from developed meta-model for an example dataset
#
# Now that we have developed a meta-model to estimate monopile damage based on input data, we can input measured data from the North Sea at the FINO1 research platform (www.fino1.de). A data set named "fino1_hourly_aug2019_aug2020.csv" is provide in the root folder, containing hourly input data, and whether the turbine would be parked or operational (a known factor based on the wind speed).
#
# Firstly, import this datasets.

# %%
data_hourly=pd.read_csv('gdrive/My Drive/HullUniversity_AI_Sustanability_Hackathon_Project2/fino1_hourly_aug2019_aug2020.csv')

# %% [markdown]
# Given that the inputs to out model were scaled, we need to apply the same scaling transfer to the measured data we are going to apply to the meta-model. Also, as during model development, we need to reshape the dataset.

# %%
data_hourly=FNL_input_scaler.transform(data_hourly)
data_hourly_input = data_hourly.reshape(data_hourly.shape[0], data_hourly.shape[1], 1)

# %% [markdown]
# We can now input our measured dataset into the model to determine the corresponding damage value calculated by the meta-model.

# %%
D_hourly_Pred=model.predict(data_hourly_input)

# %% [markdown]
# Given that the output damage values form the meta-model are normalised, we must apply the inverse transformation function.

# %%
D_hourly_Pred_true=FNL_output_scaler.inverse_transform(D_hourly_Pred)

# %% [markdown]
# We now have a series of damage fraction values corresponding to measured conditions, based on the model predicts. These values can now be used to estiamte the damage accumulated over the one year period.
#
#
#
# # *End of example*
